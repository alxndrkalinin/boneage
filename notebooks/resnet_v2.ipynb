# %% [markdown]
# ### Imports

# %%
from __future__ import division, print_function
from collections import OrderedDict

import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, StratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
from torchvision.models.inception import model_urls
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# import sparseconvnet.legacy as scn

import matplotlib.pyplot as plt
import time
import os
import cv2
from PIL import Image, ImageChops

plt.ion()   # interactive mode
# %matplotlib inline
# %env TMP="/tmp"
# %env JOBLIB_TEMP_FOLDER="/tmp"
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: TMP="/tmp"
# env: JOBLIB_TEMP_FOLDER="/tmp"
# env: CUDA_VISIBLE_DEVICES=1

# %%
def summary(input_size, model):
    def register_hook(module):
        def hook(module, input, output):
            class_name = str(module.__class__).split('.')[-1].split("'")[0]
            module_idx = len(summary)

            m_key = '%s-%i' % (class_name, module_idx+1)
            summary[m_key] = OrderedDict()
            summary[m_key]['input_shape'] = list(input[0].size())
            summary[m_key]['input_shape'][0] = -1
            summary[m_key]['output_shape'] = list(output.size())
            summary[m_key]['output_shape'][0] = -1

            params = 0
            if hasattr(module, 'weight'):
                params += torch.prod(torch.LongTensor(list(module.weight.size())))
                if module.weight.requires_grad:
                    summary[m_key]['trainable'] = True
                else:
                    summary[m_key]['trainable'] = False
            if hasattr(module, 'bias'):
                params +=  torch.prod(torch.LongTensor(list(module.bias.size())))
            summary[m_key]['nb_params'] = params

        if not isinstance(module, nn.Sequential) and \
           not isinstance(module, nn.ModuleList) and \
           not (module == model):
            hooks.append(module.register_forward_hook(hook))

    # check if there are multiple inputs to the network
    if isinstance(input_size[0], (list, tuple)):
        x = [Variable(torch.rand(1,*in_size)) for in_size in input_size]
    else:
        x = Variable(torch.rand(1,*input_size))

    # create properties
    summary = OrderedDict()
    hooks = []
    # register hook
    model.apply(register_hook)
    # make a forward pass
    model(x)
    # remove these hooks
    for h in hooks:
        h.remove()

    return summary

# %% [markdown]
# ### Data

# %%
TRAIN_DIR = '../data/boneage-training-dataset/'
TEST_DIR = '../data/boneage-validation-dataset/'
TRAIN_LABEL = '../data/train.csv'
TEST_LABEL = '../data/dataset_data_file-validation-gender-fa677c87-bd0d-44a1-92f3-f5966389798b.csv'
FILETYPE = '.png'
img_scale = 256
img_size = 244
n_channels = 3

use_gpu = torch.cuda.is_available()

# %% [markdown]
# ### Dataset class

# %%
class BoneAgeDataset(Dataset):
    """Bone Age dataset."""

    def __init__(self, root_dir, labels, filetype, img_size, transform=None, mode='train'):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.labels = labels
        self.root_dir = root_dir
        self.transform = transform
        self.filetype = filetype
        self.img_size = img_size
        self.clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
        self.training = True if mode == 'train' else False
        self.predicting = True if mode == 'pred' else False

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
#         print(idx)
#         sample = 1.0
        img_name = os.path.join(self.root_dir, str(self.labels.iloc[idx]['id']) + self.filetype)
        img = Image.open(img_name).convert('RGB')
#         print(img_name, img.size)
        
        # randomize thresholding
        if self.training:
            img = img.point(lambda x: x if x < np.random.randint(200,220) else 0)
        else:
            img = img.point(lambda x: x if x < 220 else 0)
            
        # resizing
#         print('PIL size:', img.size)
        img = np.asarray(img)
#         print('Np size: ',img.shape)
        if img.shape[1] > img.shape[0]:
#             print(img.shape)
            img = np.swapaxes(img,0,1)
    
        img = cv2.resize(img, (img_scale,img_scale))

#         img = cv2.resize(img, (img_scale,img_scale+210))
#         img = img[210:,:]
#         print(img.shape)

        # rotation
        if self.training:
            rot_ang = range(0,360,30)
            rot_ang = rot_ang[np.random.randint(0,len(rot_ang))]
    #         print(rot_ang)
            scale = np.random.uniform(0.8,1.2)
    #         print(scale)
            rot_mat = cv2.getRotationMatrix2D((img.shape[0]/2,img.shape[1]/2), rot_ang, scale);
            img = cv2.warpAffine(img, rot_mat, (img.shape[0],img.shape[1]))
        
        # randomize thresholding
        if self.training:
            thresh_block_size = np.random.randint(5,9) // 2 * 2 + 1
            thresh_param = np.random.randint(5,9)
        else:
            thresh_block_size = 7
            thresh_param = 7
        
        img_he = self.clahe.apply(cv2.convertScaleAbs(img[:,:,0]))
        img_mask = cv2.adaptiveThreshold(img_he, 1, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,
                                         thresh_block_size, thresh_param)
        img_ch = img_he * img_mask
        
        if n_channels == 1:
            img = img_ch
        elif n_channels == 3:
            for i in xrange(img.shape[2]):
                img[:,:,i] = img_ch
        else:
            print('\n Wrong number of channels \n')

        img = Image.fromarray(np.uint8(img))
#         print('Img:', img.size)
        
#         image = cv2.imread(img_name)[:,:,::-1]
        gender = self.labels.iloc[idx]['male'].astype(np.int32)
        pat_id = self.labels.iloc[idx]['id'].astype(np.int32)
        
        if not self.predicting:
            boneage = self.labels.iloc[idx]['boneage'].astype(np.float32)
            label = np.hstack((boneage, gender, pat_id))
        else:
            label = np.hstack((gender, pat_id))
#         print(label)

        if self.transform:
            img = self.transform(img)
            
        sample = {'image': img, 'label': label}

        return sample

# %% [markdown]
# ### Transforms

# %%
data_transforms = {
    'train': transforms.Compose([
#         transforms.Scale(300),
#         transforms.CenterCrop(384),
        transforms.RandomSizedCrop(img_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
#         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
#         transforms.Scale(300),
        transforms.CenterCrop(img_size),
        transforms.ToTensor(),
#         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'pred': transforms.Compose([
#         transforms.Scale(300),
        transforms.CenterCrop(img_size),
        transforms.ToTensor(),
#         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# ### Data loaders

# %%
labels = pd.read_csv(TRAIN_LABEL, dtype=np.uint16)
labels = labels[labels['male']==0]
labels = labels.reset_index()
bins = xrange(40)
labels['bins'] = np.digitize(labels['boneage'], bins=bins)

# %%
skf = StratifiedKFold(n_splits=7)
# skf = KFold(n_splits=7)
splits = []
for train, test in skf.split(np.zeros(len(labels)), labels['bins']):
    fold_label = {
        'train': labels.loc[train, ('id', 'boneage', 'male')],
        'val': labels.loc[test, ('id', 'boneage', 'male')]
    }
    splits.append(fold_label)
# Out:
# /home/user/software/miniconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:597: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=7.
#   % (min_groups, self.n_splits)), Warning)

# %%
# splits[0]['train']['boneage'].hist()

# %%
# splits[0]['val']['boneage'].hist()

# %%
fold_label = splits[0]

# %%
image_datasets = {x: BoneAgeDataset(TRAIN_DIR, fold_label[x], FILETYPE, img_size, data_transforms[x], x)
                  for x in ['train', 'val']}
dataloders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=64, shuffle=True, num_workers=12, pin_memory=True)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
print(dataset_sizes)
# Out:
# {'train': 4944, 'val': 834}

# %%
for i_batch, sample in enumerate(dataloders['val']):
    print(i_batch, sample['image'].size())
    print(i_batch, sample['image'].mean())
#     for i in xrange(sample['image'].size()[0]):
#         img = sample['image'][i,0,:,:].numpy()
#         plt.figure()
#         plt.imshow(img, cmap=plt.cm.gray)
    if i_batch == 0:
        break
# Out:
# 0 torch.Size([64, 3, 244, 244])
# 0 0.232455238896

# %% [markdown]
# ### Training

# %%
model_urls['inception_v3_google'] = model_urls['inception_v3_google'].replace('https://', 'http://')

class Net(nn.Module):
    def __init__(self, input_shape=(n_channels, img_size, img_size)):
        super(Net, self).__init__()
        
#         # inception_v3
#         self.bn = nn.BatchNorm2d(input_shape[0])
#         resnet = models.inception_v3(pretrained=True)
        
#         num_ftrs = resnet.fc.in_features
#         resnet.fc = nn.Linear(num_ftrs, 1)
        
#         num_ftrs_aux = resnet.AuxLogits.fc.in_features
#         resnet.AuxLogits.fc = nn.Linear(num_ftrs_aux, 1)
        
#         self.resnet = resnet
        
        # resnet
#         self.bn = nn.BatchNorm2d(input_shape[0])
        resnet = models.resnet50(pretrained=True)
        for param in resnet.parameters():
            param.requires_grad = False
        num_ftrs = resnet.fc.in_features
        boneage_clf = nn.Sequential(
            nn.Dropout(),
            nn.Linear(num_ftrs, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(1024, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 1)
        )
        resnet.fc = boneage_clf
        self.resnet = resnet

#         self.net = nn.Sequential(
#             nn.Conv2d(input_shape[0], 192, 5, stride=3),
#             nn.BatchNorm2d(192),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(192, 160, 1, stride=1),
#             nn.BatchNorm2d(160),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(160, 96, 1, stride=1),
#             nn.BatchNorm2d(96),
#             nn.ReLU(inplace=True),
            
#             nn.MaxPool2d(3, stride=2, ceil_mode=True),
#             nn.Dropout(),
            
#             nn.Conv2d(96, 192, 5, stride=2),
#             nn.BatchNorm2d(192),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(192, 192, 1, stride=1),
#             nn.BatchNorm2d(192),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(192, 192, 1, stride=1),
#             nn.BatchNorm2d(192),
#             nn.ReLU(inplace=True),
            
#             nn.AvgPool2d(3, stride=2, ceil_mode=True),
#             nn.Dropout(),
        
#             nn.Conv2d(192, 192, 3),
#             nn.BatchNorm2d(192),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(192, 192, 1, stride=1),
#             nn.BatchNorm2d(192),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(192, 1, 1, stride=1),
#             nn.BatchNorm2d(1),
#             nn.ReLU(inplace=True)
                                 
# #             nn.AvgPool2d(12, stride=12, ceil_mode=True)
#         )
#         self.boneage_clf = nn.Sequential(
#             nn.Dropout(),
#             nn.Linear(32*32, 512),
#             nn.ReLU(inplace=True),
#             nn.Dropout(),
#             nn.Linear(512, 128),
#             nn.ReLU(inplace=True),
#             nn.Linear(128, 1)
#         )
#         self.gender_clf = nn.Sequential(
#             nn.Dropout(),
#             nn.Linear(32*32, 512),
#             nn.ReLU(inplace=True),
#             nn.Dropout(),
#             nn.Linear(512, 128),
#             nn.ReLU(inplace=True),
#             nn.Linear(128, 1)
#         )
        
#         resnet.avgpool = nn.AdaptiveAvgPool2d(2)
#         num_ftrs = net.fc.in_features
#         net.fc = nn.Linear(num_ftrs, 1)
#         self.net = net

    def forward(self, x):

        x = self.resnet(x)
        
#         x = self.net(self.bn(x))
#         x = self.net(x)
#         print(x.size())
#         x = x.view(-1, 32*32)
#         g_x = self.gender_clf(x)
#         ba_x = self.boneage_clf(x)
#         x = F.relu(self.lin128(F.dropout(x)))
#         x = self.lin1(F.dropout(x))
#         x = self.resnet(self.bn(x))
#         return ba_x
#         return ba_x, g_x
        return x
    
model = Net([n_channels, img_size, img_size])
    
# print(summary([3, 640, 640], model))
print(model)

if use_gpu:
    model.cuda()
# Out:
# Net (
#   (resnet): ResNet (
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU (inplace)
#     (maxpool): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (layer1): Sequential (
#       (0): Bottleneck (
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (downsample): Sequential (
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): Bottleneck (
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (2): Bottleneck (
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#     )
#     (layer2): Sequential (
#       (0): Bottleneck (
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (downsample): Sequential (
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): Bottleneck (
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (2): Bottleneck (
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (3): Bottleneck (
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#     )
#     (layer3): Sequential (
#       (0): Bottleneck (
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (downsample): Sequential (
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): Bottleneck (
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (2): Bottleneck (
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (3): Bottleneck (
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (4): Bottleneck (
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (5): Bottleneck (
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#     )
#     (layer4): Sequential (
#       (0): Bottleneck (
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (downsample): Sequential (
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): Bottleneck (
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#       (2): Bottleneck (
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#       )
#     )
#     (avgpool): AvgPool2d (size=7, stride=7, padding=0, ceil_mode=False, count_include_pad=True)
#     (fc): Sequential (
#       (0): Dropout (p = 0.5)
#       (1): Linear (2048 -> 1024)
#       (2): ReLU (inplace)
#       (3): Dropout (p = 0.5)
#       (4): Linear (1024 -> 256)
#       (5): ReLU (inplace)
#       (6): Linear (256 -> 1)
#     )
#   )
# )

# %%
model.load_state_dict(torch.load('../models/10-4-2000-resnet50-0fold7-fem-02-02.pth'))

# %%
lr = 0.001
# momentum = 0.9
# optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
optimizer = optim.Adam(model.resnet.fc.parameters(), lr=lr, weight_decay=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# %%
def pearsonr(x, y):
    x = x.view(-1)
    mean_x = torch.mean(x)
    mean_y = torch.mean(y)
    xm = x.sub(mean_x)
    ym = y.sub(mean_y)
    r_num = xm.dot(ym)
    r_den = torch.norm(xm, 2) * torch.norm(ym, 2)
    r_val = r_num / r_den
    return r_val

def ccc(x, y):
#     print('X:', x)
    mean_x = torch.mean(x)
#     print('Mean x:', mean_x)
    mean_y = torch.mean(y)
#     print('Mean y:', mean_y)
    xm = x.sub(mean_x)
    ym = y.sub(mean_y)
    xn = torch.norm(xm, 2)
#     print('Xn:', xn)
    yn = torch.norm(ym, 2)
#     print('Yn:', yn)
    xydot = ym.dot(xm.view(-1))
#     print('XYdot:', xydot)

    ccc_num = 2 * xydot / xm.size()[0]
#     print('CCC num:', ccc_num)
    ccc_den = xn + yn + torch.pow(mean_x.sub(mean_y), 2)
#     print('CCC den:', ccc_den)

    ccc = ccc_num / ccc_den
    return ccc
    

def train(epoch, train_loader):
    since = time.time()
    exp_lr_scheduler.step()
    model.train()
    
    train_boneage_loss = 0
    train_gender_loss = 0
    train_loss = 0
    train_ccc = 0
    num_samp = len(train_loader.dataset)
    
    for batch_idx, sample in enumerate(train_loader):
        data = sample['image']
        target = sample['label'].float()
        if use_gpu:
            data, target = data.cuda(async=True), target.cuda()
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        
        ba_output = model(data)
        
        # 2 heads MTL output
#         ba_output, g_output = model(data)
#         print(output1)
#         print(output2)
        
#         for i in xrange(output.size[0]):
#             if output[i,1] > 0.5:
#                 output[i,0] = (output[i,0] // 6) * 6
#             else:
#                 output[i,0] = (output[i,0] // 2) * 2

#         boneage_out = torch.round(output[:,0].div(6)).mul(6)
#         boneage_out = output[:,0]

#         boneage_loss = F.l1_loss(output.view(-1), target[:,0])
#         train_boneage_loss += boneage_loss.data[0]
        boneage_loss = F.smooth_l1_loss(ba_output.view(-1), target[:,0])
        train_boneage_loss += boneage_loss.data[0]
        
#         gender_loss = F.binary_cross_entropy_with_logits(g_output.view(-1), target[:,1])
#         train_gender_loss += gender_loss.data[0]
        
#         loss = 0.75 * boneage_loss + 0.25 * gender_loss
        loss = boneage_loss
#         loss = gender_loss
#         loss = F.l1_loss(output1.view(-1), target[:,0]) + F.l1_loss(output2.view(-1), target[:,0])
#         loss = 0.8 * F.l1_loss(output.view(-1), target[:,0]) + 0.2 * F.binary_cross_entropy(F.sigmoid(output.view(-1)), target[:,1])
#         loss = F.l1_loss(output.view(-1), target[:,0])
        
        train_loss += loss.data[0]
#         c = ccc(boneage_out, target[:,0])
        c = ccc(ba_output, target[:,0])
        train_ccc += c.data.cpu().numpy()[0]
        
        loss.backward()
        optimizer.step()
#         if batch_idx % (1000 // len(target)) == 0:
#     print('Train ep: {} [{}/{} ({:.0f}%)]\tBoneAge Loss: {:.4f}\tGender Loss: {:.4f}\t Loss: {:.4f}\tCCC: {:.4f}'.format(
#         epoch, batch_idx * len(data), num_samp,
#         100. * batch_idx / num_samp, train_boneage_loss / num_samp,
#         train_gender_loss / num_samp, train_loss / num_samp,
#         train_ccc / num_samp))
    
    print('\nTrain Epoch: {} [{}/{} ({:.0f}%)]\t Loss: {:.4f}\tCCC: {:.4f}'.format(
        epoch, batch_idx * len(data), num_samp,
        100. * batch_idx / num_samp, train_loss / num_samp, train_ccc / num_samp))
    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

def test(test_loader):
    since = time.time()
    model.eval()
    
    test_avg_gender = 0
    test_boneage_loss = 0
    test_boneage_l1_loss = 0
    test_boneage_round_loss = 0
    test_boneage_round_loss_2 = 0
    test_boneage_round_loss_6 = 0
    test_gender_loss = 0
    test_loss = 0
    test_ccc = 0
    test_pearsonr = 0
    
    num_samp = len(test_loader.dataset)
    for sample in test_loader:
        data = sample['image']
        target = sample['label'].float()
        if use_gpu:
            data, target = data.cuda(async=True), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target)

#         test_avg_gender += sample['label'][:,1].sum()
        ba_output = model(data)
        
        # 2 heads MTL output
#         ba_output, g_output = model(data)
#         print(ba_output)
        
#         print(output.size())
#         boneage_out = torch.round(output[:,0].div(6)).mul(6)
#         boneage_out = output[:,0]
#         print(boneage_out)
#         print(target[:,0])
#         boneage_loss = F.l1_loss(output.view(-1), target[:,0])

        boneage_loss = F.smooth_l1_loss(ba_output.view(-1), target[:,0])
        boneage_l1_loss = F.l1_loss(ba_output.view(-1), target[:,0])
# #         print(boneage_loss)
        boneage_round_loss = F.l1_loss(torch.round(ba_output.view(-1)), target[:,0])
# #         print(boneage_round_loss)
        boneage_round_loss_2 = F.l1_loss(torch.round(ba_output.view(-1).div(2)).mul(2), target[:,0])
# #         print(boneage_round_loss_2)
        boneage_round_loss_6 = F.l1_loss(torch.round(ba_output.view(-1).div(6)).mul(6), target[:,0])
# #         print(boneage_round_loss_6)
        
        test_boneage_loss += boneage_loss.data[0]
        test_boneage_l1_loss += boneage_l1_loss.data[0]
        test_boneage_round_loss += boneage_round_loss.data[0]
        test_boneage_round_loss_2 += boneage_round_loss_2.data[0]
        test_boneage_round_loss_6 += boneage_round_loss_6.data[0]
    
#         print(test_boneage_loss)
#         gender_loss = F.binary_cross_entropy_with_logits(g_output.view(-1), target[:,1])
#         test_gender_loss += gender_loss.data[0]

#         loss = 0.75 * boneage_loss + 0.25 * gender_loss
        loss = boneage_loss
#         loss = 0.8 * F.l1_loss(output.view(-1), target[:,0]) + 0.2 * F.binary_cross_entropy(F.sigmoid(output.view(-1)), target[:,1])
#         loss = F.l1_loss(output.view(-1), target[:,0])

        test_loss += loss.data[0]
#         c = ccc(boneage_out, target[:,0])
        c = ccc(ba_output, target[:,0])
        r = pearsonr(ba_output, target[:,0])
        test_ccc += c.data.cpu().numpy()[0]
        test_pearsonr += r.data.cpu().numpy()[0]

    print('\nTest set: BoneAge loss: {:.4f}, loss: {:.4f}, CCC: {:.4f}, R: {:.4f}'.format(
        test_boneage_loss / num_samp, test_loss / num_samp, test_ccc / num_samp, test_pearsonr / num_samp))
    print('Test set: L1 loss: {:.4f},Round loss: {:.4f}, Round2 loss: {:.4f}, Round6: {:.4f}, Gender: {:.4f}'.format(
        test_boneage_l1_loss / num_samp, test_boneage_round_loss / num_samp, test_boneage_round_loss_2 / num_samp,
        test_boneage_round_loss_6 / num_samp, test_avg_gender / num_samp))
    
#     print('\nTest set: Avg loss: {:.4f} CCC: {:.4f}\n'.format(
#         test_loss / num_samp, test_ccc / num_samp))
    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    
    return test_boneage_l1_loss / num_samp

# %%
# best_loss = 100
for epoch in range(1, 4 + 1):
    for phase in ['train', 'val']:
        if phase == 'train':
            train(epoch, dataloders[phase])
        if phase == 'val':
            test(dataloders[phase])

# %%
for param in model.parameters():
    param.requires_grad = True
lr = 0.001
# momentum = 0.9
# optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# %%
for epoch in range(1, 60 + 1):
    for phase in ['train', 'val']:
        if phase == 'train':
            train(epoch, dataloders[phase])
        if phase == 'val':
            test(dataloders[phase])

# %%
# resuming train

best_loss = test(dataloders['val'])
best_model_wts = model.state_dict()

for param in model.parameters():
    param.requires_grad = True

lr = 0.0001
# momentum = 0.9
# optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)

for epoch in range(1, 60 + 1):
    for phase in ['train', 'val']:
        if phase == 'train':
            train(epoch, dataloders[phase])
        if phase == 'val':
            epoch_val_loss = test(dataloders[phase])
            if epoch_val_loss < best_loss:
                best_loss = epoch_val_loss
                best_model_wts = model.state_dict()
                print('Saved model weights.')
# Out:
# Test set: BoneAge loss: 0.3529, loss: 0.3529, CCC: 0.0481, R: 0.0146
# Test set: L1 loss: 0.3611,Round loss: 0.3610, Round2 loss: 0.3612, Round6: 0.3618, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 1 [1232/4944 (2%)]	 Loss: 0.2127	CCC: 0.0586
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2492, loss: 0.2492, CCC: 0.0726, R: 0.0149
# Test set: L1 loss: 0.2575,Round loss: 0.2574, Round2 loss: 0.2572, Round6: 0.2545, Gender: 0.0000
# Training complete in 0m 8s
#
# Saved model weights.
#
# Train Epoch: 2 [1232/4944 (2%)]	 Loss: 0.2068	CCC: 0.0586
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2309, loss: 0.2309, CCC: 0.1016, R: 0.0150
# Test set: L1 loss: 0.2392,Round loss: 0.2398, Round2 loss: 0.2400, Round6: 0.2401, Gender: 0.0000
# Training complete in 0m 7s
#
# Saved model weights.
#
# Train Epoch: 3 [1232/4944 (2%)]	 Loss: 0.2050	CCC: 0.0596
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2296, loss: 0.2296, CCC: 0.0610, R: 0.0127
# Test set: L1 loss: 0.2379,Round loss: 0.2381, Round2 loss: 0.2383, Round6: 0.2370, Gender: 0.0000
# Training complete in 0m 9s
#
# Saved model weights.
#
# Train Epoch: 4 [1232/4944 (2%)]	 Loss: 0.1980	CCC: 0.0611
# Training complete in 1m 4s
#
# Test set: BoneAge loss: 0.2156, loss: 0.2156, CCC: 0.0684, R: 0.0151
# Test set: L1 loss: 0.2237,Round loss: 0.2236, Round2 loss: 0.2246, Round6: 0.2249, Gender: 0.0000
# Training complete in 0m 8s
#
# Saved model weights.
#
# Train Epoch: 5 [1232/4944 (2%)]	 Loss: 0.2023	CCC: 0.0598
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2428, loss: 0.2428, CCC: 0.0620, R: 0.0127
# Test set: L1 loss: 0.2511,Round loss: 0.2509, Round2 loss: 0.2503, Round6: 0.2524, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 6 [1232/4944 (2%)]	 Loss: 0.1951	CCC: 0.0607
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2186, loss: 0.2186, CCC: 0.0745, R: 0.0151
# Test set: L1 loss: 0.2269,Round loss: 0.2266, Round2 loss: 0.2269, Round6: 0.2238, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 7 [1232/4944 (2%)]	 Loss: 0.1907	CCC: 0.0622
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2482, loss: 0.2482, CCC: 0.0669, R: 0.0149
# Test set: L1 loss: 0.2564,Round loss: 0.2566, Round2 loss: 0.2559, Round6: 0.2560, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 8 [1232/4944 (2%)]	 Loss: 0.1942	CCC: 0.0604
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2456, loss: 0.2456, CCC: 0.0643, R: 0.0150
# Test set: L1 loss: 0.2539,Round loss: 0.2534, Round2 loss: 0.2533, Round6: 0.2531, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 9 [1232/4944 (2%)]	 Loss: 0.1978	CCC: 0.0606
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2625, loss: 0.2625, CCC: 0.0644, R: 0.0150
# Test set: L1 loss: 0.2708,Round loss: 0.2709, Round2 loss: 0.2708, Round6: 0.2718, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 10 [1232/4944 (2%)]	 Loss: 0.1906	CCC: 0.0617
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2410, loss: 0.2410, CCC: 0.0654, R: 0.0153
# Test set: L1 loss: 0.2493,Round loss: 0.2493, Round2 loss: 0.2489, Round6: 0.2524, Gender: 0.0000
# Training complete in 0m 9s
#
#
# Train Epoch: 11 [1232/4944 (2%)]	 Loss: 0.1871	CCC: 0.0629
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2379, loss: 0.2379, CCC: 0.0875, R: 0.0150
# Test set: L1 loss: 0.2461,Round loss: 0.2463, Round2 loss: 0.2458, Round6: 0.2456, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 12 [1232/4944 (2%)]	 Loss: 0.1904	CCC: 0.0611
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2420, loss: 0.2420, CCC: 0.0637, R: nan
# Test set: L1 loss: 0.2502,Round loss: 0.2497, Round2 loss: 0.2500, Round6: 0.2526, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 13 [1232/4944 (2%)]	 Loss: 0.1903	CCC: 0.0618
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2432, loss: 0.2432, CCC: 0.0712, R: 0.0153
# Test set: L1 loss: 0.2515,Round loss: 0.2515, Round2 loss: 0.2515, Round6: 0.2531, Gender: 0.0000
# Training complete in 0m 9s
#
#
# Train Epoch: 14 [1232/4944 (2%)]	 Loss: 0.1900	CCC: 0.0623
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2193, loss: 0.2193, CCC: 0.0875, R: 0.0152
# Test set: L1 loss: 0.2276,Round loss: 0.2277, Round2 loss: 0.2285, Round6: 0.2318, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 15 [1232/4944 (2%)]	 Loss: 0.1850	CCC: 0.0631
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2177, loss: 0.2177, CCC: 0.1164, R: 0.0153
# Test set: L1 loss: 0.2259,Round loss: 0.2265, Round2 loss: 0.2256, Round6: 0.2252, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 16 [1232/4944 (2%)]	 Loss: 0.1872	CCC: 0.0621
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2170, loss: 0.2170, CCC: 0.0675, R: 0.0129
# Test set: L1 loss: 0.2253,Round loss: 0.2255, Round2 loss: 0.2251, Round6: 0.2235, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 17 [1232/4944 (2%)]	 Loss: 0.1867	CCC: 0.0618
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2130, loss: 0.2130, CCC: 0.0771, R: 0.0152
# Test set: L1 loss: 0.2212,Round loss: 0.2209, Round2 loss: 0.2215, Round6: 0.2211, Gender: 0.0000
# Training complete in 0m 8s
#
# Saved model weights.
#
# Train Epoch: 18 [1232/4944 (2%)]	 Loss: 0.1899	CCC: 0.0620
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2148, loss: 0.2148, CCC: 0.0740, R: 0.0152
# Test set: L1 loss: 0.2231,Round loss: 0.2232, Round2 loss: 0.2229, Round6: 0.2232, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 19 [1232/4944 (2%)]	 Loss: 0.1848	CCC: 0.0626
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2235, loss: 0.2235, CCC: 0.0976, R: 0.0151
# Test set: L1 loss: 0.2317,Round loss: 0.2312, Round2 loss: 0.2319, Round6: 0.2326, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 20 [1232/4944 (2%)]	 Loss: 0.1882	CCC: 0.0625
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2126, loss: 0.2126, CCC: 0.0805, R: 0.0153
# Test set: L1 loss: 0.2209,Round loss: 0.2205, Round2 loss: 0.2203, Round6: 0.2207, Gender: 0.0000
# Training complete in 0m 7s
#
# Saved model weights.
#
# Train Epoch: 21 [1232/4944 (2%)]	 Loss: 0.1816	CCC: 0.0616
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2067, loss: 0.2067, CCC: 0.1001, R: 0.0153
# Test set: L1 loss: 0.2150,Round loss: 0.2152, Round2 loss: 0.2139, Round6: 0.2134, Gender: 0.0000
# Training complete in 0m 7s
#
# Saved model weights.
#
# Train Epoch: 22 [1232/4944 (2%)]	 Loss: 0.1848	CCC: 0.0628
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1993, loss: 0.1993, CCC: 0.0695, R: 0.0153
# Test set: L1 loss: 0.2075,Round loss: 0.2072, Round2 loss: 0.2081, Round6: 0.2081, Gender: 0.0000
# Training complete in 0m 7s
#
# Saved model weights.
#
# Train Epoch: 23 [1232/4944 (2%)]	 Loss: 0.1806	CCC: 0.0633
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2136, loss: 0.2136, CCC: 0.0672, R: 0.0129
# Test set: L1 loss: 0.2218,Round loss: 0.2217, Round2 loss: 0.2217, Round6: 0.2214, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 24 [1232/4944 (2%)]	 Loss: 0.1770	CCC: 0.0636
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2170, loss: 0.2170, CCC: 0.0687, R: nan
# Test set: L1 loss: 0.2252,Round loss: 0.2254, Round2 loss: 0.2256, Round6: 0.2261, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 25 [1232/4944 (2%)]	 Loss: 0.1784	CCC: 0.0628
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2023, loss: 0.2023, CCC: 0.0913, R: 0.0153
# Test set: L1 loss: 0.2106,Round loss: 0.2104, Round2 loss: 0.2097, Round6: 0.2103, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 26 [1232/4944 (2%)]	 Loss: 0.1799	CCC: 0.0631
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2057, loss: 0.2057, CCC: 0.0770, R: 0.0153
# Test set: L1 loss: 0.2139,Round loss: 0.2135, Round2 loss: 0.2131, Round6: 0.2105, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 27 [1232/4944 (2%)]	 Loss: 0.1822	CCC: 0.0630
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1976, loss: 0.1976, CCC: 0.0818, R: 0.0153
# Test set: L1 loss: 0.2058,Round loss: 0.2053, Round2 loss: 0.2059, Round6: 0.2057, Gender: 0.0000
# Training complete in 0m 6s
#
# Saved model weights.
#
# Train Epoch: 28 [1232/4944 (2%)]	 Loss: 0.1819	CCC: 0.0623
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1958, loss: 0.1958, CCC: 0.0875, R: 0.0153
# Test set: L1 loss: 0.2041,Round loss: 0.2045, Round2 loss: 0.2026, Round6: 0.2038, Gender: 0.0000
# Training complete in 0m 7s
#
# Saved model weights.
# Train Epoch: 29 [1232/4944 (2%)]	 Loss: 0.1785	CCC: 0.0625
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2154, loss: 0.2154, CCC: 0.0897, R: 0.0153
# Test set: L1 loss: 0.2237,Round loss: 0.2234, Round2 loss: 0.2246, Round6: 0.2233, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 30 [1232/4944 (2%)]	 Loss: 0.1763	CCC: 0.0634
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2103, loss: 0.2103, CCC: 0.0748, R: 0.0153
# Test set: L1 loss: 0.2184,Round loss: 0.2183, Round2 loss: 0.2174, Round6: 0.2196, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 31 [1232/4944 (2%)]	 Loss: 0.1817	CCC: 0.0622
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2177, loss: 0.2177, CCC: 0.0899, R: 0.0153
# Test set: L1 loss: 0.2260,Round loss: 0.2262, Round2 loss: 0.2265, Round6: 0.2263, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 32 [1232/4944 (2%)]	 Loss: 0.1811	CCC: 0.0628
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2116, loss: 0.2116, CCC: 0.0711, R: 0.0153
# Test set: L1 loss: 0.2199,Round loss: 0.2199, Round2 loss: 0.2197, Round6: 0.2213, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 33 [1232/4944 (2%)]	 Loss: 0.1828	CCC: 0.0634
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2068, loss: 0.2068, CCC: 0.0717, R: 0.0153
# Test set: L1 loss: 0.2150,Round loss: 0.2149, Round2 loss: 0.2156, Round6: 0.2167, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 34 [1232/4944 (2%)]	 Loss: 0.1804	CCC: 0.0629
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1964, loss: 0.1964, CCC: 0.0997, R: 0.0153
# Test set: L1 loss: 0.2046,Round loss: 0.2051, Round2 loss: 0.2042, Round6: 0.2027, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 35 [1232/4944 (2%)]	 Loss: 0.1787	CCC: 0.0633
# Training complete in 1m 4s
#
# Test set: BoneAge loss: 0.2376, loss: 0.2376, CCC: 0.0713, R: 0.0153
# Test set: L1 loss: 0.2459,Round loss: 0.2459, Round2 loss: 0.2455, Round6: 0.2417, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 36 [1232/4944 (2%)]	 Loss: 0.1766	CCC: 0.0634
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2237, loss: 0.2237, CCC: 0.0667, R: 0.0129
# Test set: L1 loss: 0.2320,Round loss: 0.2320, Round2 loss: 0.2311, Round6: 0.2281, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 37 [1232/4944 (2%)]	 Loss: 0.1795	CCC: 0.0628
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2042, loss: 0.2042, CCC: 0.0834, R: 0.0154
# Test set: L1 loss: 0.2125,Round loss: 0.2133, Round2 loss: 0.2122, Round6: 0.2120, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 38 [1232/4944 (2%)]	 Loss: 0.1814	CCC: 0.0628
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2052, loss: 0.2052, CCC: 0.0690, R: nan
# Test set: L1 loss: 0.2134,Round loss: 0.2133, Round2 loss: 0.2141, Round6: 0.2139, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 39 [1232/4944 (2%)]	 Loss: 0.1746	CCC: 0.0630
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2717, loss: 0.2717, CCC: 0.0719, R: 0.0154
# Test set: L1 loss: 0.2800,Round loss: 0.2800, Round2 loss: 0.2798, Round6: 0.2771, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 40 [1232/4944 (2%)]	 Loss: 0.1803	CCC: 0.0635
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1985, loss: 0.1985, CCC: 0.0725, R: 0.0153
# Test set: L1 loss: 0.2066,Round loss: 0.2068, Round2 loss: 0.2054, Round6: 0.2023, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 41 [1232/4944 (2%)]	 Loss: 0.1811	CCC: 0.0616
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2168, loss: 0.2168, CCC: 0.0795, R: 0.0153
# Test set: L1 loss: 0.2250,Round loss: 0.2250, Round2 loss: 0.2251, Round6: 0.2251, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 42 [1232/4944 (2%)]	 Loss: 0.1778	CCC: 0.0630
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2054, loss: 0.2054, CCC: 0.0899, R: 0.0153
# Test set: L1 loss: 0.2136,Round loss: 0.2142, Round2 loss: 0.2134, Round6: 0.2124, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 43 [1232/4944 (2%)]	 Loss: 0.1785	CCC: 0.0636
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2153, loss: 0.2153, CCC: 0.0723, R: 0.0153
# Test set: L1 loss: 0.2236,Round loss: 0.2235, Round2 loss: 0.2238, Round6: 0.2204, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 44 [1232/4944 (2%)]	 Loss: 0.1768	CCC: 0.0633
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1968, loss: 0.1968, CCC: 0.1117, R: 0.0153
# Test set: L1 loss: 0.2048,Round loss: 0.2048, Round2 loss: 0.2041, Round6: 0.2022, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 45 [1232/4944 (2%)]	 Loss: 0.1778	CCC: 0.0639
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2014, loss: 0.2014, CCC: 0.0827, R: 0.0153
# Test set: L1 loss: 0.2097,Round loss: 0.2093, Round2 loss: 0.2109, Round6: 0.2079, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 46 [1232/4944 (2%)]	 Loss: 0.1791	CCC: 0.0635
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2128, loss: 0.2128, CCC: 0.0700, R: 0.0154
# Test set: L1 loss: 0.2211,Round loss: 0.2214, Round2 loss: 0.2216, Round6: 0.2216, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 47 [1232/4944 (2%)]	 Loss: 0.1757	CCC: 0.0640
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1969, loss: 0.1969, CCC: 0.0900, R: 0.0153
# Test set: L1 loss: 0.2051,Round loss: 0.2047, Round2 loss: 0.2057, Round6: 0.2040, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 48 [1232/4944 (2%)]	 Loss: 0.1751	CCC: 0.0637
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1991, loss: 0.1991, CCC: 0.0720, R: 0.0153
# Test set: L1 loss: 0.2073,Round loss: 0.2077, Round2 loss: 0.2069, Round6: 0.2077, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 49 [1232/4944 (2%)]	 Loss: 0.1740	CCC: 0.0639
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1993, loss: 0.1993, CCC: 0.0828, R: 0.0153
# Test set: L1 loss: 0.2076,Round loss: 0.2078, Round2 loss: 0.2076, Round6: 0.2043, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 50 [1232/4944 (2%)]	 Loss: 0.1816	CCC: 0.0621
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2136, loss: 0.2136, CCC: 0.0754, R: 0.0153
# Test set: L1 loss: 0.2219,Round loss: 0.2220, Round2 loss: 0.2223, Round6: 0.2218, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 51 [1232/4944 (2%)]	 Loss: 0.1786	CCC: 0.0628
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2179, loss: 0.2179, CCC: 0.0715, R: 0.0153
# Test set: L1 loss: 0.2262,Round loss: 0.2260, Round2 loss: 0.2260, Round6: 0.2254, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 52 [1232/4944 (2%)]	 Loss: 0.1769	CCC: 0.0635
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2164, loss: 0.2164, CCC: 0.0697, R: 0.0153
# Test set: L1 loss: 0.2247,Round loss: 0.2247, Round2 loss: 0.2246, Round6: 0.2267, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 53 [1232/4944 (2%)]	 Loss: 0.1793	CCC: 0.0630
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2110, loss: 0.2110, CCC: 0.0709, R: 0.0153
# Test set: L1 loss: 0.2192,Round loss: 0.2195, Round2 loss: 0.2185, Round6: 0.2193, Gender: 0.0000
# Training complete in 0m 6s

# %%
lr = 0.00001
# momentum = 0.9
# optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)

for epoch in range(1, 60 + 1):
    for phase in ['train', 'val']:
        if phase == 'train':
            train(epoch, dataloders[phase])
        if phase == 'val':
            epoch_val_loss = test(dataloders[phase])
            if epoch_val_loss < best_loss:
                best_loss = epoch_val_loss
                best_model_wts = model.state_dict()
                print('Saved model weights.')
# Out:
# Train Epoch: 1 [1232/4944 (2%)]	 Loss: 0.1759	CCC: 0.0628
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2150, loss: 0.2150, CCC: 0.0701, R: nan
# Test set: L1 loss: 0.2233,Round loss: 0.2229, Round2 loss: 0.2235, Round6: 0.2222, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 2 [1232/4944 (2%)]	 Loss: 0.1794	CCC: 0.0628
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2002, loss: 0.2002, CCC: 0.0767, R: 0.0154
# Test set: L1 loss: 0.2085,Round loss: 0.2085, Round2 loss: 0.2090, Round6: 0.2075, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 3 [1232/4944 (2%)]	 Loss: 0.1761	CCC: 0.0627
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2054, loss: 0.2054, CCC: 0.0792, R: 0.0154
# Test set: L1 loss: 0.2136,Round loss: 0.2140, Round2 loss: 0.2126, Round6: 0.2143, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 4 [1232/4944 (2%)]	 Loss: 0.1804	CCC: 0.0622
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2026, loss: 0.2026, CCC: 0.0844, R: 0.0153
# Test set: L1 loss: 0.2108,Round loss: 0.2106, Round2 loss: 0.2107, Round6: 0.2117, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 5 [1232/4944 (2%)]	 Loss: 0.1774	CCC: 0.0635
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2160, loss: 0.2160, CCC: 0.0705, R: 0.0154
# Test set: L1 loss: 0.2242,Round loss: 0.2239, Round2 loss: 0.2240, Round6: 0.2267, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 6 [1232/4944 (2%)]	 Loss: 0.1742	CCC: 0.0633
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.1979, loss: 0.1979, CCC: 0.0937, R: 0.0154
# Test set: L1 loss: 0.2062,Round loss: 0.2062, Round2 loss: 0.2060, Round6: 0.2034, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 7 [1232/4944 (2%)]	 Loss: 0.1768	CCC: 0.0636
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1986, loss: 0.1986, CCC: 0.0916, R: 0.0153
# Test set: L1 loss: 0.2068,Round loss: 0.2066, Round2 loss: 0.2065, Round6: 0.2064, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 8 [1232/4944 (2%)]	 Loss: 0.1742	CCC: 0.0636
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2086, loss: 0.2086, CCC: 0.0985, R: 0.0154
# Test set: L1 loss: 0.2168,Round loss: 0.2166, Round2 loss: 0.2169, Round6: 0.2170, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 9 [1232/4944 (2%)]	 Loss: 0.1766	CCC: 0.0631
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2129, loss: 0.2129, CCC: 0.0868, R: 0.0154
# Test set: L1 loss: 0.2212,Round loss: 0.2213, Round2 loss: 0.2201, Round6: 0.2179, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 10 [1232/4944 (2%)]	 Loss: 0.1738	CCC: 0.0640
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.1952, loss: 0.1952, CCC: 0.0720, R: 0.0153
# Test set: L1 loss: 0.2034,Round loss: 0.2035, Round2 loss: 0.2037, Round6: 0.2027, Gender: 0.0000
# Training complete in 0m 8s
#
# Saved model weights.
#
# Train Epoch: 11 [1232/4944 (2%)]	 Loss: 0.1752	CCC: 0.0639
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2133, loss: 0.2133, CCC: 0.0708, R: 0.0154
# Test set: L1 loss: 0.2215,Round loss: 0.2213, Round2 loss: 0.2207, Round6: 0.2220, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 12 [1232/4944 (2%)]	 Loss: 0.1758	CCC: 0.0638
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2069, loss: 0.2069, CCC: 0.0707, R: 0.0130
# Test set: L1 loss: 0.2151,Round loss: 0.2149, Round2 loss: 0.2160, Round6: 0.2182, Gender: 0.0000
# Training complete in 0m 9s
#
#
# Train Epoch: 13 [1232/4944 (2%)]	 Loss: 0.1761	CCC: 0.0630
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2108, loss: 0.2108, CCC: 0.0920, R: 0.0154
# Test set: L1 loss: 0.2190,Round loss: 0.2187, Round2 loss: 0.2190, Round6: 0.2215, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 14 [1232/4944 (2%)]	 Loss: 0.1782	CCC: 0.0639
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1987, loss: 0.1987, CCC: 0.0822, R: 0.0154
# Test set: L1 loss: 0.2069,Round loss: 0.2066, Round2 loss: 0.2063, Round6: 0.2038, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 15 [1232/4944 (2%)]	 Loss: 0.1782	CCC: 0.0633
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2093, loss: 0.2093, CCC: 0.0758, R: 0.0153
# Test set: L1 loss: 0.2175,Round loss: 0.2177, Round2 loss: 0.2168, Round6: 0.2190, Gender: 0.0000
# Training complete in 0m 9s
#
#
# Train Epoch: 16 [1232/4944 (2%)]	 Loss: 0.1745	CCC: 0.0639
# Training complete in 1m 4s
#
# Test set: BoneAge loss: 0.2117, loss: 0.2117, CCC: 0.0922, R: 0.0153
# Test set: L1 loss: 0.2198,Round loss: 0.2199, Round2 loss: 0.2199, Round6: 0.2219, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 17 [1232/4944 (2%)]	 Loss: 0.1740	CCC: 0.0644
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2066, loss: 0.2066, CCC: 0.0989, R: 0.0154
# Test set: L1 loss: 0.2149,Round loss: 0.2158, Round2 loss: 0.2149, Round6: 0.2146, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 18 [1232/4944 (2%)]	 Loss: 0.1733	CCC: 0.0638
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2009, loss: 0.2009, CCC: 0.0988, R: 0.0153
# Test set: L1 loss: 0.2092,Round loss: 0.2088, Round2 loss: 0.2104, Round6: 0.2123, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 19 [1232/4944 (2%)]	 Loss: 0.1749	CCC: 0.0634
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1973, loss: 0.1973, CCC: 0.0980, R: 0.0153
# Test set: L1 loss: 0.2055,Round loss: 0.2058, Round2 loss: 0.2049, Round6: 0.2046, Gender: 0.0000
# Training complete in 0m 9s
#
#
# Train Epoch: 20 [1232/4944 (2%)]	 Loss: 0.1738	CCC: 0.0639
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2192, loss: 0.2192, CCC: 0.0922, R: 0.0154
# Test set: L1 loss: 0.2274,Round loss: 0.2274, Round2 loss: 0.2267, Round6: 0.2262, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 21 [1232/4944 (2%)]	 Loss: 0.1735	CCC: 0.0644
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2120, loss: 0.2120, CCC: 0.0834, R: 0.0153
# Test set: L1 loss: 0.2202,Round loss: 0.2204, Round2 loss: 0.2212, Round6: 0.2213, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 22 [1232/4944 (2%)]	 Loss: 0.1748	CCC: 0.0635
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2040, loss: 0.2040, CCC: 0.0710, R: 0.0153
# Test set: L1 loss: 0.2122,Round loss: 0.2124, Round2 loss: 0.2118, Round6: 0.2119, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 23 [1232/4944 (2%)]	 Loss: 0.1776	CCC: 0.0636
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2073, loss: 0.2073, CCC: 0.0696, R: nan
# Test set: L1 loss: 0.2155,Round loss: 0.2150, Round2 loss: 0.2151, Round6: 0.2155, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 24 [1232/4944 (2%)]	 Loss: 0.1714	CCC: 0.0638
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2019, loss: 0.2019, CCC: 0.0743, R: 0.0153
# Test set: L1 loss: 0.2102,Round loss: 0.2098, Round2 loss: 0.2104, Round6: 0.2093, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 25 [1232/4944 (2%)]	 Loss: 0.1732	CCC: 0.0638
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2035, loss: 0.2035, CCC: 0.0719, R: 0.0153
# Test set: L1 loss: 0.2117,Round loss: 0.2111, Round2 loss: 0.2115, Round6: 0.2118, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 26 [1232/4944 (2%)]	 Loss: 0.1760	CCC: 0.0645
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2024, loss: 0.2024, CCC: 0.0861, R: 0.0153
# Test set: L1 loss: 0.2106,Round loss: 0.2110, Round2 loss: 0.2101, Round6: 0.2100, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 27 [1232/4944 (2%)]	 Loss: 0.1693	CCC: 0.0651
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2143, loss: 0.2143, CCC: 0.0671, R: 0.0129
# Test set: L1 loss: 0.2225,Round loss: 0.2222, Round2 loss: 0.2222, Round6: 0.2210, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 28 [1232/4944 (2%)]	 Loss: 0.1718	CCC: 0.0638
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1960, loss: 0.1960, CCC: 0.0865, R: 0.0153
# Test set: L1 loss: 0.2041,Round loss: 0.2040, Round2 loss: 0.2049, Round6: 0.2052, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 29 [1232/4944 (2%)]	 Loss: 0.1733	CCC: 0.0633
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2050, loss: 0.2050, CCC: 0.0776, R: 0.0153
# Test set: L1 loss: 0.2132,Round loss: 0.2132, Round2 loss: 0.2127, Round6: 0.2129, Gender: 0.0000
# Training complete in 0m 6s
# Train Epoch: 30 [1232/4944 (2%)]	 Loss: 0.1713	CCC: 0.0645
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2221, loss: 0.2221, CCC: 0.0712, R: 0.0153
# Test set: L1 loss: 0.2304,Round loss: 0.2300, Round2 loss: 0.2292, Round6: 0.2274, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 31 [1232/4944 (2%)]	 Loss: 0.1727	CCC: 0.0634
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2134, loss: 0.2134, CCC: 0.0896, R: 0.0153
# Test set: L1 loss: 0.2216,Round loss: 0.2213, Round2 loss: 0.2209, Round6: 0.2193, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 32 [1232/4944 (2%)]	 Loss: 0.1775	CCC: 0.0632
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2098, loss: 0.2098, CCC: 0.0708, R: 0.0130
# Test set: L1 loss: 0.2180,Round loss: 0.2179, Round2 loss: 0.2182, Round6: 0.2163, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 33 [1232/4944 (2%)]	 Loss: 0.1754	CCC: 0.0642
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2097, loss: 0.2097, CCC: 0.0748, R: 0.0154
# Test set: L1 loss: 0.2179,Round loss: 0.2181, Round2 loss: 0.2177, Round6: 0.2171, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 34 [1232/4944 (2%)]	 Loss: 0.1708	CCC: 0.0643
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2029, loss: 0.2029, CCC: 0.0910, R: 0.0154
# Test set: L1 loss: 0.2112,Round loss: 0.2112, Round2 loss: 0.2095, Round6: 0.2082, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 35 [1232/4944 (2%)]	 Loss: 0.1739	CCC: 0.0643
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2041, loss: 0.2041, CCC: 0.0708, R: 0.0154
# Test set: L1 loss: 0.2123,Round loss: 0.2121, Round2 loss: 0.2123, Round6: 0.2150, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 36 [1232/4944 (2%)]	 Loss: 0.1743	CCC: 0.0633
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2083, loss: 0.2083, CCC: 0.0874, R: 0.0153
# Test set: L1 loss: 0.2165,Round loss: 0.2168, Round2 loss: 0.2159, Round6: 0.2160, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 37 [1232/4944 (2%)]	 Loss: 0.1745	CCC: 0.0641
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2277, loss: 0.2277, CCC: 0.0658, R: 0.0129
# Test set: L1 loss: 0.2359,Round loss: 0.2359, Round2 loss: 0.2360, Round6: 0.2362, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 38 [1232/4944 (2%)]	 Loss: 0.1754	CCC: 0.0636
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1956, loss: 0.1956, CCC: 0.0836, R: 0.0153
# Test set: L1 loss: 0.2038,Round loss: 0.2041, Round2 loss: 0.2035, Round6: 0.2020, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 39 [1232/4944 (2%)]	 Loss: 0.1745	CCC: 0.0639
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2115, loss: 0.2115, CCC: 0.0736, R: 0.0153
# Test set: L1 loss: 0.2198,Round loss: 0.2199, Round2 loss: 0.2205, Round6: 0.2215, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 40 [1232/4944 (2%)]	 Loss: 0.1735	CCC: 0.0645
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2000, loss: 0.2000, CCC: 0.0707, R: 0.0129
# Test set: L1 loss: 0.2082,Round loss: 0.2083, Round2 loss: 0.2071, Round6: 0.2091, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 41 [1232/4944 (2%)]	 Loss: 0.1755	CCC: 0.0636
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1930, loss: 0.1930, CCC: 0.0885, R: 0.0153
# Test set: L1 loss: 0.2012,Round loss: 0.2010, Round2 loss: 0.2015, Round6: 0.2001, Gender: 0.0000
# Training complete in 0m 7s
#
# Saved model weights.
#
# Train Epoch: 42 [1232/4944 (2%)]	 Loss: 0.1766	CCC: 0.0625
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2053, loss: 0.2053, CCC: 0.0700, R: 0.0129
# Test set: L1 loss: 0.2134,Round loss: 0.2137, Round2 loss: 0.2126, Round6: 0.2112, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 43 [1232/4944 (2%)]	 Loss: 0.1768	CCC: 0.0642
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2150, loss: 0.2150, CCC: 0.0714, R: 0.0153
# Test set: L1 loss: 0.2232,Round loss: 0.2226, Round2 loss: 0.2235, Round6: 0.2217, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 44 [1232/4944 (2%)]	 Loss: 0.1708	CCC: 0.0643
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2024, loss: 0.2024, CCC: 0.0693, R: 0.0129
# Test set: L1 loss: 0.2106,Round loss: 0.2103, Round2 loss: 0.2115, Round6: 0.2113, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 45 [1232/4944 (2%)]	 Loss: 0.1756	CCC: 0.0640
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1978, loss: 0.1978, CCC: 0.0884, R: 0.0153
# Test set: L1 loss: 0.2061,Round loss: 0.2066, Round2 loss: 0.2053, Round6: 0.2054, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 46 [1232/4944 (2%)]	 Loss: 0.1706	CCC: 0.0643
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.1918, loss: 0.1918, CCC: 0.0950, R: 0.0154
# Test set: L1 loss: 0.1999,Round loss: 0.1996, Round2 loss: 0.1991, Round6: 0.1976, Gender: 0.0000
# Training complete in 0m 9s
#
# Saved model weights.
#
# Train Epoch: 47 [1232/4944 (2%)]	 Loss: 0.1741	CCC: 0.0635
# Training complete in 1m 4s
#
# Test set: BoneAge loss: 0.1959, loss: 0.1959, CCC: 0.1062, R: 0.0154
# Test set: L1 loss: 0.2041,Round loss: 0.2042, Round2 loss: 0.2045, Round6: 0.2029, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 48 [1232/4944 (2%)]	 Loss: 0.1676	CCC: 0.0648
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.1948, loss: 0.1948, CCC: 0.1247, R: 0.0153
# Test set: L1 loss: 0.2030,Round loss: 0.2022, Round2 loss: 0.2042, Round6: 0.2050, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 49 [1232/4944 (2%)]	 Loss: 0.1786	CCC: 0.0634
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2005, loss: 0.2005, CCC: 0.0707, R: 0.0129
# Test set: L1 loss: 0.2085,Round loss: 0.2085, Round2 loss: 0.2086, Round6: 0.2083, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 50 [1232/4944 (2%)]	 Loss: 0.1759	CCC: 0.0633
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2126, loss: 0.2126, CCC: 0.0700, R: nan
# Test set: L1 loss: 0.2208,Round loss: 0.2205, Round2 loss: 0.2205, Round6: 0.2212, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 51 [1232/4944 (2%)]	 Loss: 0.1735	CCC: 0.0639
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2027, loss: 0.2027, CCC: 0.1157, R: 0.0153
# Test set: L1 loss: 0.2109,Round loss: 0.2109, Round2 loss: 0.2107, Round6: 0.2095, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 52 [1232/4944 (2%)]	 Loss: 0.1713	CCC: 0.0648
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2127, loss: 0.2127, CCC: 0.0812, R: 0.0154
# Test set: L1 loss: 0.2209,Round loss: 0.2211, Round2 loss: 0.2213, Round6: 0.2230, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 53 [1232/4944 (2%)]	 Loss: 0.1714	CCC: 0.0649
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2026, loss: 0.2026, CCC: 0.0733, R: 0.0154
# Test set: L1 loss: 0.2108,Round loss: 0.2109, Round2 loss: 0.2105, Round6: 0.2116, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 54 [1232/4944 (2%)]	 Loss: 0.1743	CCC: 0.0640
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2021, loss: 0.2021, CCC: 0.0696, R: 0.0130
# Test set: L1 loss: 0.2103,Round loss: 0.2104, Round2 loss: 0.2098, Round6: 0.2119, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 55 [1232/4944 (2%)]	 Loss: 0.1771	CCC: 0.0632
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1975, loss: 0.1975, CCC: 0.0837, R: 0.0154
# Test set: L1 loss: 0.2058,Round loss: 0.2056, Round2 loss: 0.2069, Round6: 0.2053, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 56 [1232/4944 (2%)]	 Loss: 0.1769	CCC: 0.0634
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.1993, loss: 0.1993, CCC: 0.0793, R: 0.0153
# Test set: L1 loss: 0.2075,Round loss: 0.2066, Round2 loss: 0.2069, Round6: 0.2077, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 57 [1232/4944 (2%)]	 Loss: 0.1711	CCC: 0.0643
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2076, loss: 0.2076, CCC: 0.0720, R: nan
# Test set: L1 loss: 0.2158,Round loss: 0.2156, Round2 loss: 0.2157, Round6: 0.2150, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 58 [1232/4944 (2%)]	 Loss: 0.1727	CCC: 0.0646
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2061, loss: 0.2061, CCC: 0.0836, R: 0.0153
# Test set: L1 loss: 0.2143,Round loss: 0.2143, Round2 loss: 0.2146, Round6: 0.2159, Gender: 0.0000
# Training complete in 0m 6s
# Train Epoch: 59 [1232/4944 (2%)]	 Loss: 0.1737	CCC: 0.0643
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2057, loss: 0.2057, CCC: 0.0714, R: 0.0153
# Test set: L1 loss: 0.2140,Round loss: 0.2140, Round2 loss: 0.2141, Round6: 0.2114, Gender: 0.0000
# Training complete in 0m 6s
#
#
# Train Epoch: 60 [1232/4944 (2%)]	 Loss: 0.1731	CCC: 0.0642
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2043, loss: 0.2043, CCC: 0.0782, R: 0.0154
# Test set: L1 loss: 0.2126,Round loss: 0.2123, Round2 loss: 0.2127, Round6: 0.2136, Gender: 0.0000
# Training complete in 0m 6s

# %%
lr = 0.0001
# momentum = 0.9
# optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

for epoch in range(1, 60 + 1):
    for phase in ['train', 'val']:
        if phase == 'train':
            train(epoch, dataloders[phase])
        if phase == 'val':
            epoch_val_loss = test(dataloders[phase])
            if epoch_val_loss < best_loss:
                best_loss = epoch_val_loss
                best_model_wts = model.state_dict()
                print('Saved model weights.')
# Out:
# Train Epoch: 1 [1232/4944 (2%)]	 Loss: 0.1797	CCC: 0.0632
# Training complete in 1m 0s
#
# Test set: BoneAge loss: 0.2104, loss: 0.2104, CCC: 0.0735, R: 0.0152
# Test set: L1 loss: 0.2186,Round loss: 0.2188, Round2 loss: 0.2178, Round6: 0.2176, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 2 [1232/4944 (2%)]	 Loss: 0.1778	CCC: 0.0623
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2049, loss: 0.2049, CCC: 0.0839, R: 0.0153
# Test set: L1 loss: 0.2131,Round loss: 0.2131, Round2 loss: 0.2132, Round6: 0.2137, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 3 [1232/4944 (2%)]	 Loss: 0.1778	CCC: 0.0634
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2091, loss: 0.2091, CCC: 0.0773, R: 0.0154
# Test set: L1 loss: 0.2173,Round loss: 0.2173, Round2 loss: 0.2173, Round6: 0.2156, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 4 [1232/4944 (2%)]	 Loss: 0.1770	CCC: 0.0633
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2112, loss: 0.2112, CCC: 0.0995, R: 0.0153
# Test set: L1 loss: 0.2195,Round loss: 0.2197, Round2 loss: 0.2186, Round6: 0.2193, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 5 [1232/4944 (2%)]	 Loss: 0.1816	CCC: 0.0631
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2285, loss: 0.2285, CCC: 0.0827, R: 0.0153
# Test set: L1 loss: 0.2368,Round loss: 0.2363, Round2 loss: 0.2370, Round6: 0.2363, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 6 [1232/4944 (2%)]	 Loss: 0.1758	CCC: 0.0641
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2322, loss: 0.2322, CCC: 0.0799, R: 0.0153
# Test set: L1 loss: 0.2405,Round loss: 0.2405, Round2 loss: 0.2401, Round6: 0.2402, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 7 [1232/4944 (2%)]	 Loss: 0.1794	CCC: 0.0630
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2168, loss: 0.2168, CCC: 0.0804, R: 0.0152
# Test set: L1 loss: 0.2250,Round loss: 0.2253, Round2 loss: 0.2249, Round6: 0.2241, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 8 [1232/4944 (2%)]	 Loss: 0.1836	CCC: 0.0618
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2046, loss: 0.2046, CCC: 0.0742, R: 0.0153
# Test set: L1 loss: 0.2129,Round loss: 0.2128, Round2 loss: 0.2139, Round6: 0.2139, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 9 [1232/4944 (2%)]	 Loss: 0.1842	CCC: 0.0626
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2071, loss: 0.2071, CCC: 0.0758, R: 0.0154
# Test set: L1 loss: 0.2153,Round loss: 0.2156, Round2 loss: 0.2160, Round6: 0.2168, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 10 [1232/4944 (2%)]	 Loss: 0.1781	CCC: 0.0633
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2142, loss: 0.2142, CCC: 0.0727, R: 0.0129
# Test set: L1 loss: 0.2225,Round loss: 0.2221, Round2 loss: 0.2228, Round6: 0.2205, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 11 [1232/4944 (2%)]	 Loss: 0.1730	CCC: 0.0641
# Training complete in 1m 3s
#
# Test set: BoneAge loss: 0.2069, loss: 0.2069, CCC: 0.0765, R: 0.0154
# Test set: L1 loss: 0.2151,Round loss: 0.2147, Round2 loss: 0.2148, Round6: 0.2177, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 12 [1232/4944 (2%)]	 Loss: 0.1758	CCC: 0.0631
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2136, loss: 0.2136, CCC: 0.0798, R: 0.0154
# Test set: L1 loss: 0.2218,Round loss: 0.2215, Round2 loss: 0.2217, Round6: 0.2230, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 13 [1232/4944 (2%)]	 Loss: 0.1758	CCC: 0.0631
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2042, loss: 0.2042, CCC: 0.0727, R: nan
# Test set: L1 loss: 0.2125,Round loss: 0.2125, Round2 loss: 0.2126, Round6: 0.2099, Gender: 0.0000
# Training complete in 0m 8s
#
#
# Train Epoch: 14 [1232/4944 (2%)]	 Loss: 0.1722	CCC: 0.0642
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2150, loss: 0.2150, CCC: 0.0951, R: 0.0153
# Test set: L1 loss: 0.2231,Round loss: 0.2235, Round2 loss: 0.2236, Round6: 0.2244, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 15 [1232/4944 (2%)]	 Loss: 0.1726	CCC: 0.0640
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2041, loss: 0.2041, CCC: 0.0899, R: 0.0153
# Test set: L1 loss: 0.2123,Round loss: 0.2123, Round2 loss: 0.2122, Round6: 0.2145, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 16 [1232/4944 (2%)]	 Loss: 0.1738	CCC: 0.0635
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2248, loss: 0.2248, CCC: 0.0615, R: 0.0129
# Test set: L1 loss: 0.2330,Round loss: 0.2330, Round2 loss: 0.2337, Round6: 0.2318, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 17 [1232/4944 (2%)]	 Loss: 0.1753	CCC: 0.0637
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2046, loss: 0.2046, CCC: 0.0735, R: 0.0154
# Test set: L1 loss: 0.2129,Round loss: 0.2127, Round2 loss: 0.2127, Round6: 0.2129, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 18 [1232/4944 (2%)]	 Loss: 0.1723	CCC: 0.0638
# Training complete in 1m 1s
#
# Test set: BoneAge loss: 0.2017, loss: 0.2017, CCC: 0.0966, R: 0.0153
# Test set: L1 loss: 0.2099,Round loss: 0.2095, Round2 loss: 0.2102, Round6: 0.2104, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 19 [1232/4944 (2%)]	 Loss: 0.1743	CCC: 0.0632
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.2162, loss: 0.2162, CCC: 0.0746, R: 0.0153
# Test set: L1 loss: 0.2244,Round loss: 0.2240, Round2 loss: 0.2243, Round6: 0.2261, Gender: 0.0000
# Training complete in 0m 7s
#
#
# Train Epoch: 20 [1232/4944 (2%)]	 Loss: 0.1739	CCC: 0.0635
# Training complete in 1m 2s
#
# Test set: BoneAge loss: 0.1976, loss: 0.1976, CCC: 0.1016, R: 0.0153
# Test set: L1 loss: 0.2059,Round loss: 0.2057, Round2 loss: 0.2064, Round6: 0.2098, Gender: 0.0000
# Training complete in 0m 7s

# %%
lr = 0.00001
# momentum = 0.9
# optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

for epoch in range(1, 35 + 1):
    for phase in ['train', 'val']:
        if phase == 'train':
            train(epoch, dataloders[phase])
        if phase == 'val':
            epoch_val_loss = test(dataloders[phase])
            if epoch_val_loss < best_loss:
                best_loss = epoch_val_loss
                best_model_wts = model.state_dict()
                print('Saved model weights.')

# %% [markdown]
# #### save model

# %%
torch.save(best_model_wts, '../models/10-4-2000-resnet50-0fold7-fem-02-02.pth')

# %% [markdown]
# ### Prediction

# %%
model.load_state_dict(torch.load('../models/10-3-0320-nin-0fold-083-116.pth'))

# %%
def predict(predict_loader):
    model.eval()
    pred_gender_loss = 0
    predictions = []
    
    num_samp = len(predict_loader.dataset)
    for sample in predict_loader:
        data = sample['image']
        target = sample['label'].float()
        if use_gpu:
            data, target = data.cuda(async=True), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target)

        ba_output, g_output = model(data)
    
#         print(test_boneage_loss)
        gender_loss = F.binary_cross_entropy_with_logits(g_output.view(-1), target[:,0])
        pred_gender_loss += gender_loss.data[0]
        
        pred_labels = target[:,1].data.cpu().numpy()
#         print(pred_labels.shape)
        pred_bonage = ba_output.view(-1).data.cpu().numpy()
#         print(pred_bonage.shape)
        
        predictions.append(np.column_stack((pred_labels, pred_bonage)))

    print('\nPrediction Gender loss: {:.4f}'.format(pred_gender_loss / num_samp))
    
    return predictions

# %%
pred_labels = pd.read_csv(TEST_LABEL, dtype=int)
pred_labels.describe()

# %%
pred_image_dataset = BoneAgeDataset(TEST_DIR, pred_labels, FILETYPE, img_size, data_transforms['pred'], 'pred')
pred_dataloder = torch.utils.data.DataLoader(pred_image_dataset, batch_size=32, shuffle=True, num_workers=24,
                                             pin_memory=True)
pred_dataset_size = len(pred_image_dataset)

# %%
for i_batch, sample in enumerate(pred_dataloder):
    print(i_batch, sample['image'].size())
    print(i_batch, sample['image'].mean())
#     for i in xrange(sample['image'].size()[0]):
#         img = sample['image'][i,0,:,:].numpy()
#         plt.figure()
#         plt.imshow(img, cmap=plt.cm.gray)
    if i_batch == 2:
        break

# %%
preds = predict(pred_dataloder)

# %%
all_preds_df = pd.DataFrame(np.vstack(tuple(preds)), columns=('id', 'boneage')).sort_values('id')
all_preds_df['id'] = all_preds_df['id'].astype(int)

# %%
all_preds_df.head()

# %%
all_preds_df.tail()

# %%
all_preds_df.to_csv('../sub/10-3-0707-nin-0fold-083-116.csv', index=False)
